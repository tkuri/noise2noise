# %%
data = 'o2l2_mv_scl_air_black'
# %run train_noiseimg.py --image_dir dataset/{data}/train_A --image_dir_2 dataset/{data}/train_B --test_dir dataset/{data}/val_A --test_dir_2 dataset/{data}/val_B --image_size 128 --batch_size 8 --lr 0.001 --output_path model/{data} --nb_epochs 60 --source_noise_model clean --target_noise_model clean --val_noise_model clean
# Out:
# Using TensorFlow backend.
# Epoch 1/60
# 1000/1000 [==============================] - 550s 550ms/step - loss: 296.4966 - PSNR: 26.5537 - val_loss: 79.0531 - val_PSNR: 28.9769
#
# Epoch 00001: val_PSNR improved from -inf to 28.97691, saving model to C:\Users\kurita\work\noise2noise\model\o2l2_mv_scl_air_black/weights.001-79.053-28.97691.hdf5
# Epoch 2/60
# 1000/1000 [==============================] - 547s 547ms/step - loss: 125.1490 - PSNR: 27.2293 - val_loss: 81.7636 - val_PSNR: 28.7891
#
# Epoch 00002: val_PSNR did not improve from 28.97691
# Epoch 3/60
# 1000/1000 [==============================] - 547s 547ms/step - loss: 125.4808 - PSNR: 27.2173 - val_loss: 87.1918 - val_PSNR: 28.4666
#
# Epoch 00003: val_PSNR did not improve from 28.97691
# Epoch 4/60
# 1000/1000 [==============================] - 545s 545ms/step - loss: 124.4995 - PSNR: 27.2534 - val_loss: 84.2758 - val_PSNR: 28.6161
#
# Epoch 00004: val_PSNR did not improve from 28.97691
# Epoch 5/60
# ...

# %%
train_list = ['train', 'val', 'test']
for t in train_list:
    # %run test_model.py --weight_file .\model\o2l2_mv_scl\weights.004-74.169-28.45726.hdf5 --image_dir ../irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\{t} --test_noise_model clean --output_dir ../irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt_nr\{t}
# Out:
# ../irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0000.png
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0001.png
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0002.png
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0003.png
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0004.png
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0005.png
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0006.png
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0007.png
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0008.png
# ..\irradiance_lab\data\train_data\o2l2_mv_scl\src\irr_gt\train\extractResult_0009.png
# ...
